# %% [markdown]
# <a href="https://colab.research.google.com/github/SHAHAB-UDDIN54/Artificial-intelligence-Ai-projects/blob/main/Day_3_Ai_and_Ml_lab_work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = [10,17,19,20,23,23,45]
print("Mean",np.mean(data))
print("Median",np.median(data))
print("Std:",np.std(data))
# Out:
# Mean 22.428571428571427
# Median 20.0
# Std: 10.083326305726453

# %%
x = [1,2,3,4,5,6]
y = [9,8,7,6,5,4]
print("Corelation",np.corrcoef(x,y))
# Out:
# Corelation [[ 1. -1.]
#  [-1.  1.]]

# %% [markdown]
# # two student /user /doucuments

# %%
v1 = np.array([2,3,4])
v2 = np.array([4,6,8])
v3 =  np.array ([5,1,0])


print("Similarity v1 & v2:", np.dot(v1,v2))
print("Similarity v1 & v3:", np.dot(v1,v3))
# Out:
# Similarity v1 & v2: 58
# Similarity v1 & v3: 13
